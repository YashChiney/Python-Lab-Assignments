# %%
students=['Aarav','Isha','Rohan','Sneha','Kabir']
print(' third student',students[2])
students[2]='Rohan Patil'
print(students)
students.append("Ananya")
students.append("Vihaan")
print(students)
students.remove("Kabir")
print(students)
print("Number of students is:",len(students))
students.sort()
print(students)
backup_students=students.copy()
print(backup_students)
hackathon=['Meera','Arjun','Isha']
students.extend(hackathon)
all_participants=students.copy()
print(all_participants)
print(students)
print(hackathon)
# Out:
#  third student Rohan
# ['Aarav', 'Isha', 'Rohan Patil', 'Sneha', 'Kabir']
# ['Aarav', 'Isha', 'Rohan Patil', 'Sneha', 'Kabir', 'Ananya', 'Vihaan']
# ['Aarav', 'Isha', 'Rohan Patil', 'Sneha', 'Ananya', 'Vihaan']
# Number of students is: 6
# ['Aarav', 'Ananya', 'Isha', 'Rohan Patil', 'Sneha', 'Vihaan']
# ['Aarav', 'Ananya', 'Isha', 'Rohan Patil', 'Sneha', 'Vihaan']
# ['Aarav', 'Ananya', 'Isha', 'Rohan Patil', 'Sneha', 'Vihaan', 'Meera', 'Arjun', 'Isha']
# ['Aarav', 'Ananya', 'Isha', 'Rohan Patil', 'Sneha', 'Vihaan', 'Meera', 'Arjun', 'Isha']
# ['Meera', 'Arjun', 'Isha']
